# %%
#HERE WE WILL SCRAPE USER INFORMATION OF MR.BEAST FROM TWITTER


import pandas as pd
from ntscraper import Nitter
import ntscraper
from pprint import pprint

# %%
scraper= Nitter(log_level=1)
# Out:
# Testing instances: 100%|██████████| 77/77 [01:43<00:00,  1.35s/it]

# %%
tweets=scraper.get_tweets("mrbeast", mode="user",number=500 )
# Out:
# 23-Feb-24 13:40:52 - No instance specified, using random instance https://nitter.mint.lgbt
# 23-Feb-24 13:41:01 - Current stats for mrbeast: 18 tweets, 0 threads...
# 23-Feb-24 13:41:06 - Current stats for mrbeast: 32 tweets, 0 threads...
# 23-Feb-24 13:41:13 - Current stats for mrbeast: 43 tweets, 0 threads...
# 23-Feb-24 13:41:17 - Current stats for mrbeast: 59 tweets, 0 threads...
# 23-Feb-24 13:41:22 - Current stats for mrbeast: 74 tweets, 0 threads...
# 23-Feb-24 13:41:27 - Current stats for mrbeast: 87 tweets, 0 threads...
# 23-Feb-24 13:41:32 - Current stats for mrbeast: 96 tweets, 0 threads...
# 23-Feb-24 13:41:37 - Current stats for mrbeast: 111 tweets, 0 threads...
# 23-Feb-24 13:41:43 - Current stats for mrbeast: 125 tweets, 0 threads...
# 23-Feb-24 13:41:49 - Current stats for mrbeast: 132 tweets, 0 threads...
# 23-Feb-24 13:41:54 - Current stats for mrbeast: 145 tweets, 0 threads...
# 23-Feb-24 13:42:00 - Current stats for mrbeast: 164 tweets, 0 threads...
# ...

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'May 9, 2022 · 2:42 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': True,
#              'is-retweet': False,
#              'link': 'https://twitter.com/MrBeast/status/1523674759925760000#m',
#              'pictures': ['https://pbs.twimg.com/media/FSUuHOWXwAYplBU.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 38423,
#                        'likes': 1263270,
#                        'quotes': 12458,
#                        'retweets': 67066},
#              'text': 'No takesies backsies',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/994592419705274369/RLplF55e_bigger.jpg',
#                       'name': 'MrBeast',
#                       'profile_id': '994592419705274369',
#                       'username': '@MrBeast'},
#              'videos': []},
# ...

# %%
#data of a particular tweet which we want to retreive
data={
       'link' :[], 
       'text' :[], 
       'user' :[],
       'likes':[],
       'comments':[],
       'retweets':[],
       'external-link':[],
       'quotes': []
            }

# %%
#user defined function retreive tweets of user "mrbeast"

def create_tweets_dataset(username, no_of_tweets):


 for tweet in tweets['tweets']:
    data['link'].append(tweet['link'])
    data['text'].append(tweet['text'])
    data['user'].append(tweet['user']['name'])
    data['likes'].append(tweet['stats']['likes'])
    data['comments'].append(tweet['stats']['comments'])
    data['quotes'].append(tweet['stats']['quotes'])
    data['retweets'].append(tweet['stats']['retweets'])
    data['external-link'].append(tweet['external-link'])

# %%
#CALL THE FUNCTION

mrbeast_tweets = create_tweets_dataset("mrbeast", 500)
pprint(mrbeast_tweets)
# Out:
# None

# %%
#NOW CREATE DATAFRANE OUT OF IT
df=pd.DataFrame(data)
df.to_csv("mr_beast_csv")

# %%
df.count()
# Out:
# link             2000
# text             2000
# user             2000
# likes            2000
# comments         2000
# retweets         2000
# external-link    2000
# quotes           2000
# dtype: int64

# %%
 /FileStore/tables/elon_musk_alien_csv-1.csv

 /FileStore/tables/mr_beast_csv-2.csv
